# %% [markdown]
# <a href="https://colab.research.google.com/github/SarusanS/Smart-Sensor-Network-System-For-Structural-Health-Monitoring/blob/SARUSAN/crackSVMfold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-495dfe1c-a31d-434f-997b-0f6721e9b196" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-495dfe1c-a31d-434f-997b-0f6721e9b196">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Step 1: Upload the CSV file
from google.colab import files
uploaded = files.upload()

# Step 2: Read the uploaded file (replace with your filename)
df = pd.read_csv("your_file.csv")  # replace with the actual filename

# Step 3: Display the number of duplicates
num_duplicates = df.duplicated().sum()
print(f"🔁 Number of duplicate rows found: {num_duplicates}")

# Step 4: Remove duplicate rows
df_cleaned = df.drop_duplicates()

# Step 5: Display cleaned DataFrame info
print(f"✅ Data shape after removing duplicates: {df_cleaned.shape}")

# Step 6: Save cleaned data to new CSV file
df_cleaned.to_csv("cleaned_file.csv", index=False)
print("📁 Cleaned CSV file saved as 'cleaned_file.csv'")

# Step 7: Download the cleaned file
files.download("cleaned_file.csv")
# Out:
#      <input type="file" id="files-da68f3e8-d52e-4dad-9963-9e6474ca3e5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da68f3e8-d52e-4dad-9963-9e6474ca3e5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Step 1: Import required libraries
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report

# Step 2: Load the dataset
df = pd.read_csv("sampleOneFile (3).csv")

# Step 3: Convert 'Cracktype' to numerical labels
df['Label'] = df['CrackType'].map({'NonCrack': 0, 'Crack': 1})

# Step 4: Define features and target
X = df[['Capacitance(pF)', 'Humidity(%)', 'Temperature(C)', 'Thickness(mm)']]
y = df['Label']

# Step 5: Build the pipeline (Scaler + SVM)
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='rbf', C=1, gamma='scale'))
])

# Step 6: Perform 5-fold cross-validation and get predicted labels
y_pred_cv = cross_val_predict(pipeline, X, y, cv=5)

# Step 7: Classification report after 5-fold CV
print("📊 Classification Report (5-Fold Cross Validation):\n")
print(classification_report(y, y_pred_cv, target_names=['NonCrack', 'Crack']))

# ✅ Step 8: Print accuracy
acc = accuracy_score(y, y_pred_cv)
print(f"✅ Accuracy: {acc:.2f}")

# ✅ Step 9: Print confusion matrix
print("🧮 Confusion Matrix:")
cm = confusion_matrix(y, y_pred_cv)
print(cm)
# Out:
# 📊 Classification Report (5-Fold Cross Validation):
#
#               precision    recall  f1-score   support
#
#     NonCrack       0.46      0.44      0.45      2236
#        Crack       0.49      0.50      0.49      2358
#
#     accuracy                           0.47      4594
#    macro avg       0.47      0.47      0.47      4594
# weighted avg       0.47      0.47      0.47      4594
#
# ✅ Accuracy: 0.47
# 🧮 Confusion Matrix:
# [[ 984 1252]
#  [1171 1187]]
